# %%
# %%writefile TicTacToe.h
# #ifndef TICTACTOE_H
# #define TICTACTOE_H
#
# class TicTacToe{
#   private:
#     struct Node{
#       int moveNumber;
#       char board[9];
#       Node *nextPtr;
#     };
#
#     public:
#       TicTacToe();
#       ~TicTacToe();
#       void displayBoard(char board[]);
#       bool rangeCorrect(int cell);
#       bool cellIsEmpty(int cell, char board[]);
#       void changeTurn(char& turn);
#       bool three(char turn, char board[]);
#       bool threeInARow(char turn, char board[]);
#       bool threeInAColumn(char turn, char board[]);
#       bool threeInADiagonal(char turn, char board[]);
#       void displayList(struct Node* head);
#
# }
#
# #endif  // TICTACTOE_H
# Out:
# Overwriting TicTacToe.h

# %%
# %%writefile main.cpp
# #include <iostream>
# using namespace std;
#
#
# void displayBoard(char []);
# bool rangeCorrect(int );
# bool cellIsEmpty(int, char []);
# void changeTurn(char &);
# bool three(char, char[]);
# bool threeInARow(char, char []);
# bool threeInAColumn(char, char []);
# bool threeInADiagonal(char, char []);
#
# struct Node {
#    int moveNumber;
#    char board[9];
#    Node *nextPtr;
# };
#
# void displayList(Node *head);
# bool playAgain();
#
#
# int main() {
#     char board[9];
#     int choose;
#     bool exitProgram = false;
#     // initializing board
#     for (int i = 0; i < 9; i++)
#         board[i] = ' ';
#
#     Node *head = NULL;   // head of linked list
#     Node *tempPtr;
#
#     char turn = 'X';
#     int cell = 0;
#     bool play = true;
#
#     while (play) {
#         int moveNumber = 0;
#
#         cout << "=============================" << endl;
#         cout << "        TIC-TAC-TOE           " << endl;
#         cout << "=============================" << endl;
#         cout << "            MENU             " << endl;
#         cout << "=============================" << endl;
#         cout << "1. Play Game" << endl;
#         cout << "2. Intruction" << endl;
#         cout << "3. Exit" << endl;
#         cout << "=============================" << endl;
#         cout << "Enter your choice: ";
#         cin >> choose;
#
#         switch (choose) {
#             case 1:
#                 displayBoard(board); // displays the empty board
#                 displayList(head);
#                 while (moveNumber < 9) {
#                     cout << "*****************************" << endl;
#                     cout << "Move number: " << moveNumber << endl;
#                     cout << "TURN: " << turn << " make your move: ";
#                     cin >> cell; // this is the simple version. only input numbers here. does not check non-numeric characters..
#                     // is input correct?
#                     if (rangeCorrect(cell)) { // checking if inside the range 1-9
#                         if (cellIsEmpty(cell - 1, board)) { // checking if cell is empty. subtracting 1, because array starts from 0.
#                             board[cell - 1] = turn; // storing the move in the array
#                             if (three(turn, board)) { // checking if there are three in a row or column or diagonal
#                                 displayBoard(board); // Pass the turn to displayBoard function
#                                 cout << "Congratulations player " << turn << " You win!!" << endl;
#                                 break;
#                             }
#
#                             // creating a new Node, filling its fields and adding to the list.
#                             tempPtr = new Node;
#                             // Insert at head of list
#                             tempPtr->moveNumber = moveNumber; // copying moveNumber inside the node
#                             for (int i = 0; i < 9; i++) { // copying the elements of the board inside the board in the node
#                                 tempPtr->board[i] = board[i];
#                             }
#                             tempPtr->nextPtr = head; // the pointer of the node points to the first element of the list
#                             head = tempPtr; // the head points to the new node just created
#                             moveNumber++; // preparing for next move.
#                             changeTurn(turn); // changing the turn to the next player.
#
#                         } else { // cell was full
#                             cout << "Sorry...cell " << cell << " has already been used, try again: " << endl;
#                         }
#                     } else {
#                         cout << "Sorry...cell " << cell << " is outside the range 1-9, try again: " << endl;
#                     }
#                 }
#
#                 if (moveNumber == 9) {
#                     displayBoard(board);
#                     cout << "Game Ended: No Winners" << endl;
#                 }
#                 break;
#
#             case 2:
#                 cout << "--------- Instructions ---------" << endl;
#                 cout << "The game is played on a 3x3 grid. Each player takes turns marking a cell with their symbol ('X' or 'O'). The first player to get three of their symbols in a row, column, or diagonal wins the game. If all cells are filled and no player has won, the game is a draw." << endl;
#                 cout << "Player 1: X" << endl;
#                 cout << "Player 2: O" << endl;
#                 cout << "Good luck!" << endl;
#                 break;
#
#             case 3:
#                 exitProgram = true;
#                 play = false;
#                 break;
#
#             default:
#                 cout << "Invalid choice! Please try again." << endl;
#                 break;
#         }
#
#         if (exitProgram) {
#             cout << "Goodbye and have a great day!" << endl;
#             break;
#         }
#
#         if (playAgain()) {
#             // Reset the board and linked list for a new game
#             for (int i = 0; i < 9; i++)
#                 board[i] = ' ';
#
#             while (head != nullptr) {
#                 tempPtr = head;
#                 head = head->nextPtr;
#                 delete tempPtr;
#             }
#
#             play = true;
#         } else {
#             play = false;
#         }
#     }
#
#     return 0;
# }
#
# void displayList(Node *head) {
#     Node *tempPtr = head;  // Used to traverse list without destroying head
#     cout << "\n List contains: " << endl;
#     while (tempPtr != NULL) {
#         displayBoard(tempPtr->board);
#         cout << "Move Number: " << tempPtr->moveNumber << endl << endl;
#         tempPtr = tempPtr->nextPtr;
#     }
#     cout << "\n\n";
# }
#
# void displayBoard(char board[]) {
#     cout << "\n";
#     cout << " ___   ___   ___ " << endl;
#     cout << "| " << board[0] << " |" << " " << "| " << board[1] << " |" << " " << "| " << board[2] << " |" << endl;
#     cout << "|___| |___| |___| " << endl;
#     cout << " ___   ___   ___ " << endl;
#     cout << "| " << board[3] << " |" << " " << "| " << board[4] << " |" << " " << "| " << board[5] << " |" << endl;
#     cout << "|___| |___| |___| " << endl;
#     cout << " ___   ___   ___ " << endl;
#     cout << "| " << board[6] << " |" << " " << "| " << board[7] << " |" << " " << "| " << board[8] << " |" << endl;
#     cout << "|___| |___| |___| " << endl;
#     cout << "\n";
# }
#
# // returns true if cell is between 1 and 9
# bool rangeCorrect(int cell) {
#     // checking if cell is outside the range 1 to 9.
#     if (cell >= 1 && cell <= 9)
#         return true;
#     else
#         return false;
# }
#
# // returns true if the cell has already been used
# bool cellIsEmpty(int cell, char board[]) {
#     if (board[cell] != ' ')
#         return false;
#     else
#         return true;
# }
#
# void changeTurn(char &turn) {
#     if (turn == 'X')
#         turn = 'O';
#     else
#         turn = 'X';
# }
#
# bool three(char turn, char board[]) {
#     if (threeInARow(turn, board) || threeInAColumn(turn, board) || threeInADiagonal(turn, board))
#         return true;
#     else
#         return false;
# }
#
# bool threeInARow(char turn, char board[]) {
#     if ((board[0] == turn && board[1] == turn && board[2] == turn) ||
#         (board[3] == turn && board[4] == turn && board[5] == turn) ||
#         (board[6] == turn && board[7] == turn && board[8] == turn))
#         return true;
#     else
#         return false;
# }
#
# bool threeInAColumn(char turn, char board[]) {
#     if ((board[0] == turn && board[3] == turn && board[6] == turn) ||
#         (board[1] == turn && board[4] == turn && board[7] == turn) ||
#         (board[2] == turn && board[5] == turn && board[8] == turn))
#         return true;
#     else
#         return false;
# }
#
# bool threeInADiagonal(char turn, char board[]) {
#     if ((board[0] == turn && board[4] == turn && board[8] == turn) ||
#         (board[2] == turn && board[4] == turn && board[6] == turn))
#         return true;
#     else
#         return false;
# }
#
# bool playAgain() {
#     char choice;
#     cout << "Do you want to play again? (Y/N): ";
#     cin >> choice;
#     if (choice == 'N' || choice == 'n'){
#       cout << "Thank you for playing. Good Bye and have a great day" << endl;
#     }
#     return (choice == 'Y' || choice == 'y');
# }
# Out:
# Overwriting main.cpp

# %%
# !g++ main.cpp -o tictactoe
! ./tictactoe
# Out:
# =============================
#         TIC-TAC-TOE
# =============================
#             MENU
# =============================
# 1. Play Game
# 2. Intruction
# 3. Exit
# =============================
# Enter your choice: 2
# --------- Instructions ---------
# The game is played on a 3x3 grid. Each player takes turns marking a cell with their symbol ('X' or 'O'). The first player to get three of their symbols in a row, column, or diagonal wins the game. If all cells are filled and no player has won, the game is a draw.
# Player 1: X
# Player 2: O
# Good luck!
# Do you want to play again? (Y/N): y
# =============================
#         TIC-TAC-TOE
# =============================
#             MENU
# =============================
# 1. Play Game
# 2. Intruction
# 3. Exit
# =============================
# Enter your choice: 3
# Goodbye and have a great day!
